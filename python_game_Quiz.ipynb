# %%
print("Hello")
print("welcome to computer Quize")
playing=str(input('do you want to play  '  ))
score=0
if playing.lower() !=  "no" :

  quit()

  print("LETS PLAY THE GAME")


  answer=input("who is the president of india" )
  if answer.lower()== " droupadi murmu" :
    print("correct")
    score+= 1
  else: 
    print("incorrect")  

  answer=input("Which is the india's smallest state")
  if answer.lower()=="goa" :
    print("correct")
    score+= 1
  else: 
    print("incorrect")  


  answer=input("which city is known as the pink city of india")
  if answer.lower()==" jaipur" :
    print("correct")
    score+= 1
  else: 
    print("incorrect")  


  answer=input("which is the biggest indian state")
  if answer.lower()==" rajsthan" :
    print("correct")
    score+= 1
  else: 
    print("incorrect")  


  answer=input("who has the highest authourity in india")
  if answer.lower()==" president" :
    print("correct")
    score+= 1
  else: 
    print("incorrect")  


  answer=input("what is indias national flower")
  if answer.lower()==" lotus" :
    print("correct")
    score+= 1
  else: 
    print("incorrect")  


  answer=input("which state of india has the largest population")
  if answer.lower()==" uttar pradesh" :
    print("correct")
    score+= 1
  else: 
    print("incorrect")  


  answer=input("who is known as the iron man of india")
  if answer.lower()==" sardar vallabhbhai patel" :
    print("correct")
    score+= 1
  else: 
    print("incorrect")  


  answer=input("what is the capital of india")
  if answer.lower()==" delhi" :
    print("correct")
    score+= 1
  else: 
    print("incorrect")  


  answer=input("which is the national sport of india")
  if answer.lower()==" hockey" :
   print("correct")
   score+= 1
  else: 
   print("incorrect")  


  answer=input("where is the taj mahal located")
  if answer.lower==" agra" :
    print("correct")
    score+= 1
  else: 

    print("incorrect") 


  print("your score = ",score)
# Out:
# Hello
# welcome to computer Quize
# do you want to play  yes
# LETS PLAY THE GAME
# who is the president of indiadroupadi murmu
# correct
# Which is the india's smallest stategoa
# correct
# which city is known as the pink city of indiajaipur
# correct
# which is the biggest indian staterajsthan
# correct
# who has the highest authourity in indiapresident
# correct
# what is indias national flowerlotus
# correct
# which state of india has the largest populationuttar pradesh
# correct
# who is known as the iron man of indiafgnhskjdf
# incorrect
# what is the capital of indiadelhi
# correct
# which is the national sport of indiahockey
# correct
# where is the taj mahal locatedagra
# incorrect
# your score =  9
